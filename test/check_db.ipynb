# %%
from ase.db import connect

# %%
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_00.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_otf_1k_step.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/dft_data.db"

#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/ML_ABN_100-Ce_2L0V.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/ML_ABN_100-Ce_2L0-1V.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_00.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/ML_ABN_100-Ce_2L0V_shuffled.db"

#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_otf_1k_step.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_otf_1k_step_mlff.db"

# %%
db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_otf_1k_step_mlff.db"
db = connect(db_path)

# %% [markdown]
# ### Get column name

# %%
row_count = db.count()
print(f"Number of rows in the database: {row_count}")
# Out:
# Number of rows in the database: 1000

# %%
row = db.get(1000)

for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
# Out:
# sys_name: Ce O
# ionic_step: 1000
# file_name: OUTCAR_otf_1k_step
# is_dft: False
# id: 1000
# unique_id: a9c731c2ddbaa725a2220eecdc2781d4
# ctime: 25.069204583918395
# mtime: 25.069204583918395
# user: b37873
# numbers: [58 58 58 58 58 58 58 58  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8]
# positions: [7.31229 0.57821 2.05231], ...
# cell: [[ 7.74989032  0.          0.        ]
#  [ 0.          7.74989032  0.        ]
#  [ 0.          0.         20.48      ]]
# pbc: [ True  True  True]
# calculator: vasp
# calculator_parameters: {}
# energy: -178.72121484
# free_energy: -178.72121484
# forces: [-0.077048 -0.390169 -0.676648], ...
# stress: [ -3.10906 -19.95799  11.10064  -4.32334  -1.35387  17.6071 ]

# %% [markdown]
# ### Confirm results in data column

# %%
data_columns = row["data"]
for key, value in data_columns.items():
    print(f"{key}: {value}")

# %% [markdown]
# ### Analysis

# %%
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/dft_data.db"

# %%
"""
db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/all_data.db"
db = connect(db_path)

row_count = db.count()
print(f"Number of rows in the database: {row_count}\n")

# Get the first row
row = db.get(1)
print("First row:")
for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
print()

print("Last row:")
# Get the last row
row = db.get(row_count)
for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
"""
# Out:
# '\ndb_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/all_data.db"\ndb = connect(db_path)\n\nrow_count = db.count()\nprint(f"Number of rows in the database: {row_count}\n")\n\n# Get the first row\nrow = db.get(1)\nprint("First row:")\nfor key in row:\n    if key in ["positions", "forces"]:\n        print(f"{key}: {row[key][0]}, ...")\n    else:\n        print(f"{key}: {row[key]}")\nprint()\n\nprint("Last row:")\n# Get the last row\nrow = db.get(row_count)\nfor key in row:\n    if key in ["positions", "forces"]:\n        print(f"{key}: {row[key][0]}, ...")\n    else:\n        print(f"{key}: {row[key]}")\n'
