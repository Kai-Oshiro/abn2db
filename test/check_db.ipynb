# %%
from ase.db import connect

# %%
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/ML_ABN_100-Ce_2L0V.db"
db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_00.db"
db = connect(db_path)

# %% [markdown]
# ### Get column name

# %%
row = db.get(1)

for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
# Out:
# sys_name: Ce O
# conf_num: 1
# ctifor: 0.002
# id: 1
# unique_id: b1f0d2555937f584de2eb60de7aadb32
# ctime: 25.024774501674745
# mtime: 25.024774501674745
# user: b37873
# numbers: [58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58
#  58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58 58
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8]
# positions: [2.74    1.93747 1.93747], ...
# cell: [[16.44        0.          0.        ]
#  [ 0.         15.49978064  0.        ]
#  [ 0.          0.         22.74989032]]
# pbc: [ True  True  True]
# calculator: vasp
# calculator_parameters: {}
# free_energy: -1148.31234292
# forces: [0.007104 0.093242 2.208113], ...
# stress: [-1.280150e+00 -3.021023e+01 -1.030100e+00 -4.201000e-02 -1.530000e-03
#  -1.066400e-01]

# %% [markdown]
# ### Confirm results in data column

# %%
data_columns = row["data"]
for key, value in data_columns.items():
    print(f"{key}: {value}")
# Out:
# basis: {'Ce': [], 'O': []}
# ref_energy: [0.0, 0.0]
# mass: [140.115, 16.0]
