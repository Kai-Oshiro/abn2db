# %%
from ase.db import connect

# %%
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/ML_ABN_100-Ce_2L0V.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_00.db"
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/OUTCAR_otf_1k_step.db"
db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/dft_data.db"
db = connect(db_path)

# %% [markdown]
# ### Get column name

# %%
row_count = db.count()
print(f"Number of rows in the database: {row_count}")
# Out:
# Number of rows in the database: 119

# %%
row = db.get(1)

for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
# Out:
# sys_name: Ce O
# ionic_step: 1
# file_name: OUTCAR_otf_1k_step
# is_dft: True
# id: 1
# unique_id: 7713beafc8c2afe030d8a4b3e4b7ab7f
# ctime: 25.060749678900827
# mtime: 25.060749678900827
# user: b37873
# numbers: [58 58 58 58 58 58 58 58  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8]
# positions: [0.      1.93747 1.37   ], ...
# cell: [[ 7.74989032  0.          0.        ]
#  [ 0.          7.74989032  0.        ]
#  [ 0.          0.         20.48      ]]
# pbc: [ True  True  True]
# calculator: vasp
# calculator_parameters: {}
# energy: -176.5044534
# free_energy: -176.53455746
# forces: [-2.496000e-03  4.209000e-03  5.328734e+00], ...
# stress: [-1.667489e+01 -1.667735e+01 -4.292707e+01 -7.400000e-04 -3.330000e-03
#   3.100000e-03]

# %% [markdown]
# ### Confirm results in data column

# %%
data_columns = row["data"]
for key, value in data_columns.items():
    print(f"{key}: {value}")

# %% [markdown]
# ### Analysis

# %%
#db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/dft_data.db"
db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/all_data.db"
db = connect(db_path)

row_count = db.count()
print(f"Number of rows in the database: {row_count}\n")

# Get the first row
row = db.get(1)
print("First row:")
for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
print()

print("Last row:")
# Get the last row
row = db.get(row_count)
for key in row:
    if key in ["positions", "forces"]:
        print(f"{key}: {row[key][0]}, ...")
    else:
        print(f"{key}: {row[key]}")
# Out:
# Number of rows in the database: 1119
#
# First row:
# sys_name: Ce O
# ionic_step: 1
# file_name: OUTCAR_otf_1k_step
# is_dft: False
# id: 1
# unique_id: 4ddb7247daf40c17c5c2c5ff4ff727f6
# ctime: 25.06299823996462
# mtime: 25.06299823996462
# user: b37873
# numbers: [58 58 58 58 58 58 58 58  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8]
# positions: [0.      1.93747 1.37   ], ...
# cell: [[ 7.74989032  0.          0.        ]
#  [ 0.          7.74989032  0.        ]
#  [ 0.          0.         20.48      ]]
# pbc: [ True  True  True]
# calculator: vasp
# calculator_parameters: {}
# energy: 0.0
# free_energy: 0.0
# forces: [0. 0. 0.], ...
# stress: [0. 0. 0. 0. 0. 0.]
#
# Last row:
# sys_name: Ce O
# ionic_step: 1000
# file_name: OUTCAR_otf_1k_step
# is_dft: False
# id: 1119
# unique_id: f28a9b473b91d17b040a319ef252c74c
# ctime: 25.06299886864137
# mtime: 25.06299886864137
# user: b37873
# numbers: [58 58 58 58 58 58 58 58  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8]
# positions: [7.31229 0.57821 2.05231], ...
# cell: [[ 7.74989032  0.          0.        ]
#  [ 0.          7.74989032  0.        ]
#  [ 0.          0.         20.48      ]]
# pbc: [ True  True  True]
# calculator: vasp
# calculator_parameters: {}
# energy: -178.72121484
# free_energy: -178.72121484
# forces: [-0.077048 -0.390169 -0.676648], ...
# stress: [ -3.10906 -19.95799  11.10064  -4.32334  -1.35387  17.6071 ]
