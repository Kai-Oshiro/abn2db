# %%
from ase.db import connect

# %%
db_path = "/LARGE0/gr10563/kai/scripts/abn2db/test/ML_ABN_100-Ce_2L0V.db"
db = connect(db_path)

# %%
row = db.get(1)

for key in row:
    print(f"{key}: {row[key]}")
# Out:
# sys_name: Ce O
# conf_num: 1
# ctifor: 0.002
# id: 1
# unique_id: 581019582d625b7738123d1347b918af
# ctime: 24.97577119159263
# mtime: 24.97577119159263
# user: b37873
# numbers: [58 58 58 58 58 58 58 58  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8  8]
# positions: [[0.         1.93747258 1.37      ]
#  [3.87494516 5.81241774 1.37      ]
#  [1.93747258 0.         4.11      ]
#  [5.81241774 0.         4.11      ]
#  [1.93747258 3.87494516 4.11      ]
#  [5.81241774 3.87494516 4.11      ]
#  [0.         1.93747258 6.85      ]
#  [3.87494516 5.81241774 6.85      ]
#  [0.         0.         2.74      ]
#  [3.87494516 0.         2.74      ]
#  [1.93747258 1.93747258 2.74      ]
#  [5.81241774 1.93747258 2.74      ]
#  [0.         3.87494516 2.74      ]
#  [3.87494516 3.87494516 2.74      ]
#  [1.93747258 5.81241774 2.74      ]
#  [5.81241774 5.81241774 2.74      ]
#  [0.         0.         5.48      ]
#  [3.87494516 0.         5.48      ]
#  [1.93747258 1.93747258 5.48      ]
# ...
